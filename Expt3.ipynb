# %% [markdown]
# Name:Mayank Kapil
#
# Roll No.:C022
#
# Program/Semester:Btech Sem VIII
#
# Subject:DENSE
#
# Expt Title:a. To write a program to find multiplicative inverse a a given number in 𝑍𝑛 b. To implement Affine Cipher

# %%
import string
all_letters= string.ascii_letters 
print(all_letters)
n2=len(all_letters)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
n=[]

def gcd(n1,n2):
 
  if n2 is 0:
    #print(n1)
    #n.pop()
    n.append(n1)
    #n.pop(0)
    #x+=n
    #print(n)
    
  else:
    gcd(n2,(n1)%(n2))

# %%
class AffineCipher:
  
        
  def multiplicative_inverse(self,key,n2):
    gcd(key,n2)
    g=n[0]
    #print('G',g)

    if g == 1:
      for i in range(n2):
        result=(key*i)%n2
        if result == 1:
          print(i)
    else:
      print("Multiplicative Inverse does not exits")
    
  def encipher(self,key1,key2,p,n2):
    e=''
    for i in p:
       if i in all_letters:
         e+=all_letters[(all_letters.index(i)*key1+key2)%n2]
       else:
        e+=i
    return e
  
  def decipher(self,key1,key2,e,n2):
    d=''
    for i in e:
       if i in all_letters:
         d+=all_letters[(all_letters.index(i)*key1-key2)%n2]
       else:
        d+=i
    return d

# %%
if __name__ == "__main__":
  o=AffineCipher()
  o.multiplicative_inverse(5,52)
  #plain_text=input('Enter Plaintext:')
  #e=o.encipher(5,7,plain_text,n2)
  #print(e)
  k1=o.multiplicative_inverse(5,52)
  print(k1)
  print(type(k1))
  #d=o.decipher(k1,7,e,n2)
  #print(d)
  #o.multiplicative_inverse(7,52)
  #o.multiplicative_inverse(9,52)
# Out:
# 21
# 21
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-e66245dbfaca> in <module>()
#       5   #e=o.encipher(5,7,plain_text,n2)
#       6   #print(e)
# ----> 7   k1=o.multiplicative_inverse(5,52)*2
#       8   print(k1)
#       9   print(type(k1))
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'
